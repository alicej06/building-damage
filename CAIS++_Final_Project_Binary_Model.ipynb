# %% [markdown]
# <a href="https://colab.research.google.com/github/alicej06/building-damage/blob/main/CAIS%2B%2B_Final_Project_Binary_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Run the cell below to unzip the processed data for the binary model. Then you'll have it on the local drive, so it should be quicker to access

# %%
import shutil
import os
from google.colab import drive

# 1. Mount Drive
drive.mount('/content/drive')

# 2. Define Paths
# Where the zip lives on your Google Drive
ZIP_SOURCE = "/content/drive/My Drive/CAIS++ Mini Project + Final Project/xview2/train/processed_data/processed_dataset_binary.zip"

# Where to extract it (Local Colab Disk)
EXTRACT_DEST = "/content/dataset"

# 3. Copy & Unzip (The Fast Way)
if not os.path.exists(EXTRACT_DEST):
    print("Copying zip from Drive...")
    shutil.copy(ZIP_SOURCE, "/content/temp_data.zip")

    print("Unzipping...")
    shutil.unpack_archive("/content/temp_data.zip", EXTRACT_DEST)

    # Cleanup to save space
    os.remove("/content/temp_data.zip")
    print(f"Data ready at {EXTRACT_DEST}")
else:
    print("Data already extracted!")
# Out:
# Mounted at /content/drive
# Copying zip from Drive...
# Unzipping...
# Data ready at /content/dataset

# %% [markdown]
# 1. What the Data Looks Like
# * Images (/images):
#   * Content: 512x512 pixel chips cropped from the original (1024x1024) satellite photos.
#   * Format: Standard RGB PNG files.
#   * Source: Includes both Pre-disaster and Post-disaster images (effectively doubling your training data for localization).
# * Masks (/masks):
#   * to be used as target
#   * Content: 512x512 pixel chips matching the images exactly.
#   * Format: Grayscale PNG files.
#   * Values:
#     * 0 (Black): Background (trees, roads, water, etc.).
#     * 1 (Dark Gray/Black): Building.
#     * Note: Since the value is 1, it will look completely black if you open it in a standard image viewer. computer should still be able to read it.

# %%
import os
from glob import glob

import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, models

from tqdm.auto import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
class BinaryBuildingDataset(Dataset):
    def __init__(self, root_dir, transform=None):

        self.root_dir = root_dir
        self.img_dir = os.path.join(root_dir, "images")
        self.mask_dir = os.path.join(root_dir, "masks")
        self.transform = transform

        # collect all image paths
        self.img_paths = sorted(glob(os.path.join(self.img_dir, "*.png")))

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_path = self.img_paths[idx]
        filename = os.path.basename(img_path)''
        mask_path = os.path.join(self.mask_dir, filename)

        # load image
        img = Image.open(img_path).convert("RGB")

        # load mask as grayscale (0/1 or 0/255)
        mask = Image.open(mask_path).convert("L")
        mask_np = np.array(mask)

        # label = 1 if any building pixel exists, else 0
        has_building = 1 if np.any(mask_np > 0) else 0
        label = torch.tensor(has_building, dtype=torch.float32)

        if self.transform:
            img = self.transform(img)

        return img, label

# %%
PROCESSED_DIR = "/content/dataset"

img_size = 256
transform = transforms.Compose([
    transforms.Resize((img_size, img_size)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225],
    ),
])

full_dataset = BinaryBuildingDataset(PROCESSED_DIR, transform=transform)

len(full_dataset)
# Out:
# 50382

# %%
# Checking for class imbalance
labels = []
for i in range(min(2000, len(full_dataset))):
    _, y = full_dataset[i]
    labels.append(int(y.item()))

unique, counts = np.unique(labels, return_counts=True)
dict(zip(unique, counts))

# results: class 0 (no buildings) 788, class 1 (buildings) 1212, so class imbalance isn't too bad
# Out:
# {np.int64(0): np.int64(788), np.int64(1): np.int64(1212)}

# %%
val_frac = 0.2
val_size = int(len(full_dataset) * val_frac)
train_size = len(full_dataset) - val_size

train_ds, val_ds = random_split(
    full_dataset,
    [train_size, val_size],
    generator=torch.Generator().manual_seed(42),
)

batch_size = 32

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, num_workers=2)

len(train_ds), len(val_ds)
# Out:
# (40306, 10076)

# %%
class BuildingPresenceResNet(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
        in_features = base.fc.in_features
        base.fc = nn.Identity()
        self.backbone = base
        self.fc = nn.Linear(in_features, 1)  # single logit

    def forward(self, x):
        feats = self.backbone(x)
        logit = self.fc(feats)  # (B, 1)
        return logit.squeeze(1)  # (B,)

model = BuildingPresenceResNet().to(device)
model
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 202MB/s]
# BuildingPresenceResNet(
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Identity()
#   )
#   (fc): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

def train_one_epoch(model, loader, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for imgs, labels in tqdm(loader, desc="Train", leave=False):
        imgs = imgs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        logits = model(imgs)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * labels.size(0)

        # predictions: sigmoid > 0.5 → 1
        preds = (torch.sigmoid(logits) > 0.5).float()
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    return running_loss / total, correct / total

@torch.no_grad()
def eval_epoch(model, loader, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    for imgs, labels in tqdm(loader, desc="Val", leave=False):
        imgs = imgs.to(device)
        labels = labels.to(device)

        logits = model(imgs)
        loss = criterion(logits, labels)

        running_loss += loss.item() * labels.size(0)

        preds = (torch.sigmoid(logits) > 0.5).float()
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    return running_loss / total, correct / total

# %%
num_epochs = 5
best_val_acc = 0.0

for epoch in range(1, num_epochs + 1):
    print(f"\nEpoch {epoch}/{num_epochs}")
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, device)
    val_loss, val_acc = eval_epoch(model, val_loader, device)

    print(f"  Train loss: {train_loss:.4f}  acc: {train_acc:.4f}")
    print(f"  Val   loss: {val_loss:.4f}  acc: {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "building_presence_resnet18.pth")
        print("Saved new best model")
# Out:
# Epoch 1/5
# Train:   0%|          | 0/1260 [00:00<?, ?it/s]
# Val:   0%|          | 0/315 [00:00<?, ?it/s]
#   Train loss: 0.1731  acc: 0.9318
#   Val   loss: 0.1680  acc: 0.9346
# Saved new best model
#
# Epoch 2/5
# Train:   0%|          | 0/1260 [00:00<?, ?it/s]
# Val:   0%|          | 0/315 [00:00<?, ?it/s]
#   Train loss: 0.1006  acc: 0.9647
#   Val   loss: 0.1350  acc: 0.9501
# Saved new best model
#
# Epoch 3/5
# Train:   0%|          | 0/1260 [00:00<?, ?it/s]
# Val:   0%|          | 0/315 [00:00<?, ?it/s]
#   Train loss: 0.0623  acc: 0.9791
#   Val   loss: 0.1247  acc: 0.9579
# Saved new best model
#
# Epoch 4/5
# Train:   0%|          | 0/1260 [00:00<?, ?it/s]
# Val:   0%|          | 0/315 [00:00<?, ?it/s]
#   Train loss: 0.0456  acc: 0.9844
#   Val   loss: 0.1453  acc: 0.9609
# Saved new best model
#
# Epoch 5/5
# Train:   0%|          | 0/1260 [00:00<?, ?it/s]
# Val:   0%|          | 0/315 [00:00<?, ?it/s]
#   Train loss: 0.0343  acc: 0.9888
#   Val   loss: 0.1299  acc: 0.9610
# Saved new best model

# %%
import torch

model = BuildingPresenceResNet().to(device)
model.load_state_dict(torch.load("building_presence_resnet18.pth", map_location=device))
model.eval()

from PIL import Image
import torch.nn.functional as F

@torch.no_grad()
def predict_tile(img_path, threshold=0.5):
    """
    Run the binary model on a single tile image.
    Returns (pred_label, prob).
    """
    model.eval()
    img = Image.open(img_path).convert("RGB")
    x = transform(img).unsqueeze(0).to(device)

    logit = model(x)
    prob = torch.sigmoid(logit).item()
    pred = 1 if prob > threshold else 0

    print(f"Tile: {img_path}")
    print(f"Building presence probability: {prob:.3f}")
    print(f"Predicted class: {pred} (1 = has buildings, 0 = no buildings)")

    return pred, prob

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

model.eval()

val_labels = []
val_probs = []
val_preds = []

threshold = 0.5

for imgs, labels in val_loader:
    imgs = imgs.to(device)
    labels = labels.to(device)

    with torch.no_grad():
        logits = model(imgs)
        probs = torch.sigmoid(logits)

    val_labels.extend(labels.cpu().numpy().tolist())
    val_probs.extend(probs.cpu().numpy().tolist())
    val_preds.extend((probs > threshold).cpu().numpy().astype(int).tolist())

val_labels = np.array(val_labels, dtype=int)
val_preds = np.array(val_preds, dtype=int)

print("Confusion matrix (rows=true, cols=pred):")
print(confusion_matrix(val_labels, val_preds))

print("\nClassification report:")
print(classification_report(val_labels, val_preds,
                            target_names=["no_buildings", "has_buildings"]))
# Out:
# Confusion matrix (rows=true, cols=pred):
# [[3701  106]
#  [ 287 5982]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#  no_buildings       0.93      0.97      0.95      3807
# has_buildings       0.98      0.95      0.97      6269
#
#      accuracy                           0.96     10076
#     macro avg       0.96      0.96      0.96     10076
#  weighted avg       0.96      0.96      0.96     10076

# %%
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

model.eval()

all_paths = []
all_labels = []
all_probs = []
all_preds = []
all_is_post = []

threshold = 0.5  # tune later

for idx in tqdm(range(len(full_dataset)), desc="Batch inference"):
    img, label = full_dataset[idx]  # img is already transformed
    tile_path = full_dataset.img_paths[idx]
    is_post = 1 if "post_disaster" in os.path.basename(tile_path) else 0

    x = img.unsqueeze(0).to(device)
    label = label.item()

    with torch.no_grad():
        logit = model(x)
        prob = torch.sigmoid(logit).item()
        pred = 1 if prob > threshold else 0

    all_paths.append(tile_path)
    all_labels.append(label)
    all_probs.append(prob)
    all_preds.append(pred)
    all_is_post.append(is_post)

len(all_paths)
# Out:
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x78d05d04e2a0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1654, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1618, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 1136, in wait
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
# Batch inference:   0%|          | 0/50382 [00:00<?, ?it/s]
# 50382

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_true = np.array(all_labels, dtype=int)
y_pred = np.array(all_preds, dtype=int)

# %%
pred_df = pd.DataFrame({
    "tile_path": all_paths,
    "true_label": all_labels,
    "prob_building": all_probs,
    "pred_label": all_preds,
    "is_post_disaster": all_is_post,
})

pred_csv_path = os.path.join(PROCESSED_DIR, "binary_building_predictions.csv")
pred_df.to_csv(pred_csv_path, index=False)

pred_df.head(), pred_csv_path
# Out:
# (                                           tile_path  true_label  \
#  0  /content/dataset/images/guatemala-volcano_0000...         1.0
#  1  /content/dataset/images/guatemala-volcano_0000...         1.0
#  2  /content/dataset/images/guatemala-volcano_0000...         1.0
#  3  /content/dataset/images/guatemala-volcano_0000...         1.0
#  4  /content/dataset/images/guatemala-volcano_0000...         1.0
#
#     prob_building  pred_label  is_post_disaster
#  0       0.999767           1                 1
#  1       0.986553           1                 1
#  2       0.981644           1                 1
#  3       0.998263           1                 1
#  4       0.942191           1                 1  ,
#  '/content/dataset/binary_building_predictions.csv')

# %%
import os
import shutil
import pandas as pd

BUILDING_TILE_DIR = "/content/building_tiles_for_damage_classifier"
IMGS_OUT = os.path.join(BUILDING_TILE_DIR, "images")
MASKS_OUT = os.path.join(BUILDING_TILE_DIR, "masks")

os.makedirs(IMGS_OUT, exist_ok=True)
os.makedirs(MASKS_OUT, exist_ok=True)

MASK_DIR = os.path.join(PROCESSED_DIR, "masks")

filter_threshold = 0.5  # or use tuned threshold if you did that

export_records = []

for path, prob, is_post in zip(all_paths, all_probs, all_is_post):
    # keep only tiles that are:
    #   - predicted to contain buildings
    #   - post-disaster
    if prob > filter_threshold and is_post == 1:
        filename = os.path.basename(path)

        # copy image
        dest_img = os.path.join(IMGS_OUT, filename)
        shutil.copy2(path, dest_img)

        # copy mask (if it exists)
        src_mask = os.path.join(MASK_DIR, filename)
        if os.path.exists(src_mask):
            dest_mask = os.path.join(MASKS_OUT, filename)
            shutil.copy2(src_mask, dest_mask)

        export_records.append([filename, path, prob])

len(export_records), BUILDING_TILE_DIR
# Out:
# (15760, '/content/building_tiles_for_damage_classifier')

# %%
export_df = pd.DataFrame(
    export_records,
    columns=["filename", "orig_path", "building_prob"]
)

export_csv = os.path.join(BUILDING_TILE_DIR, "building_tiles_post_only.csv")
export_df.to_csv(export_csv, index=False)

print("Export complete!")
print(f"Images: {IMGS_OUT}")
print(f"Masks: {MASKS_OUT}")
print(f"Metadata CSV: {export_csv}")
print(f"Total tiles forwarded to damage classifier: {len(export_records)}")
# Out:
# Export complete!
# Images: /content/building_tiles_for_damage_classifier/images
# Masks: /content/building_tiles_for_damage_classifier/masks
# Metadata CSV: /content/building_tiles_for_damage_classifier/building_tiles_post_only.csv
# Total tiles forwarded to damage classifier: 15760

# %%
import os
import shutil
import pandas as pd

EXPORT_DIR = "/content/damage_classifier_input"

PRE_IMG_DIR = os.path.join(EXPORT_DIR, "pre_images")
POST_IMG_DIR = os.path.join(EXPORT_DIR, "post_images")
PRE_MASK_DIR = os.path.join(EXPORT_DIR, "pre_masks")
POST_MASK_DIR = os.path.join(EXPORT_DIR, "post_masks")

os.makedirs(PRE_IMG_DIR, exist_ok=True)
os.makedirs(POST_IMG_DIR, exist_ok=True)
os.makedirs(PRE_MASK_DIR, exist_ok=True)
os.makedirs(POST_MASK_DIR, exist_ok=True)

IMG_DIR = os.path.join(PROCESSED_DIR, "images")
MASK_DIR = os.path.join(PROCESSED_DIR, "masks")

filter_threshold = 0.5

paired_records = []

for path, prob, is_post in zip(all_paths, all_probs, all_is_post):
    # 1) we only care about post-disaster tiles that have buildings
    if is_post != 1:
        continue
    if prob <= filter_threshold:
        continue

    post_img_path = path
    fname_post = os.path.basename(post_img_path)

    # 2) derive matching pre-disaster filename for the same tile
    #    e.g. "xxx_post_disaster_tile_0.png" -> "xxx_pre_disaster_tile_0.png"
    if "post_disaster" not in fname_post:
        continue

    fname_pre = fname_post.replace("post_disaster", "pre_disaster")
    pre_img_path = os.path.join(IMG_DIR, fname_pre)

    if not os.path.exists(pre_img_path):
        # no matching pre tile for this post tile → skip
        continue

    # 3) copy images to export dirs
    dst_post_img = os.path.join(POST_IMG_DIR, fname_post)
    dst_pre_img = os.path.join(PRE_IMG_DIR, fname_pre)
    shutil.copy2(post_img_path, dst_post_img)
    shutil.copy2(pre_img_path, dst_pre_img)

    # 4) copy masks if they exist
    post_mask_src = os.path.join(MASK_DIR, fname_post)
    pre_mask_src = os.path.join(MASK_DIR, fname_pre)

    dst_post_mask = None
    dst_pre_mask = None

    if os.path.exists(post_mask_src):
        dst_post_mask = os.path.join(POST_MASK_DIR, fname_post)
        shutil.copy2(post_mask_src, dst_post_mask)

    if os.path.exists(pre_mask_src):
        dst_pre_mask = os.path.join(PRE_MASK_DIR, fname_pre)
        shutil.copy2(pre_mask_src, dst_pre_mask)

    # 5) record this pair for the CSV
    paired_records.append({
        "pre_image": dst_pre_img,
        "post_image": dst_post_img,
        "pre_mask": dst_pre_mask,
        "post_mask": dst_post_mask,
        "building_prob_post": prob,
    })

len(paired_records), EXPORT_DIR
# Out:
# (15760, '/content/damage_classifier_input')

# %%
pairs_df = pd.DataFrame(paired_records)
csv_path = os.path.join(EXPORT_DIR, "paired_building_tiles.csv")
pairs_df.to_csv(csv_path, index=False)

print("Saved paired tiles CSV to:", csv_path)
pairs_df.head()
# Out:
# Saved paired tiles CSV to: /content/damage_classifier_input/paired_building_tiles.csv
#                                            pre_image  \
# 0  /content/damage_classifier_input/pre_images/gu...
# 1  /content/damage_classifier_input/pre_images/gu...
# 2  /content/damage_classifier_input/pre_images/gu...
# 3  /content/damage_classifier_input/pre_images/gu...
# 4  /content/damage_classifier_input/pre_images/gu...
#
#                                           post_image  \
# 0  /content/damage_classifier_input/post_images/g...
# 1  /content/damage_classifier_input/post_images/g...
# 2  /content/damage_classifier_input/post_images/g...
# 3  /content/damage_classifier_input/post_images/g...
# 4  /content/damage_classifier_input/post_images/g...
#
#                                             pre_mask  \
# 0  /content/damage_classifier_input/pre_masks/gua...
# 1  /content/damage_classifier_input/pre_masks/gua...
# 2  /content/damage_classifier_input/pre_masks/gua...
# 3  /content/damage_classifier_input/pre_masks/gua...
png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/socal-fire_00001260_pre_disaster_tile_3.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/midwest-flooding_00000401_pre_disaster_tile_7.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-florence_00000501_pre_disaster_tile_0.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/socal-fire_00000087_pre_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/midwest-flooding_00000253_pre_disaster_tile_0.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000402_pre_disaster_tile_8.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-michael_00000454_pre_disaster_tile_4.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-florence_00000306_pre_disaster_tile_7.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/hurricane-michael_00000109_pre_disaster_tile_6.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000029_pre_disaster_tile_5.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000224_pre_disaster_tile_0.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/santa-rosa-wildfire_00000208_pre_disaster_tile_0.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-florence_00000067_pre_disaster_tile_6.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/socal-fire_00000221_pre_disaster_tile_2.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/midwest-flooding_00000066_pre_disaster_tile_2.png (deflated 3%)
#   adding: content/damage_classifier_input/pre_images/mexico-earthquake_00000004_pre_disaster_tile_3.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/mexico-earthquake_00000041_pre_disaster_tile_2.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/santa-rosa-wildfire_00000248_pre_disaster_tile_6.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/socal-fire_00000642_pre_disaster_tile_6.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-michael_00000311_pre_disaster_tile_8.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/midwest-flooding_00000282_pre_disaster_tile_2.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/mexico-earthquake_00000064_pre_disaster_tile_7.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/hurricane-florence_00000353_pre_disaster_tile_3.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000472_pre_disaster_tile_5.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000007_pre_disaster_tile_2.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/palu-tsunami_00000087_pre_disaster_tile_8.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/santa-rosa-wildfire_00000084_pre_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/palu-tsunami_00000071_pre_disaster_tile_0.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-michael_00000157_pre_disaster_tile_8.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-michael_00000512_pre_disaster_tile_2.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-florence_00000335_pre_disaster_tile_5.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000375_pre_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-florence_00000337_pre_disaster_tile_4.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/santa-rosa-wildfire_00000027_pre_disaster_tile_5.png (deflated 3%)
#   adding: content/damage_classifier_input/pre_images/hurricane-michael_00000548_pre_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/palu-tsunami_00000164_pre_disaster_tile_2.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/socal-fire_00000308_pre_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/socal-fire_00001254_pre_disaster_tile_4.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-matthew_00000336_pre_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/santa-rosa-wildfire_00000370_pre_disaster_tile_8.png (deflated 3%)
#   adding: content/damage_classifier_input/pre_images/hurricane-matthew_00000069_pre_disaster_tile_6.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/hurricane-florence_00000416_pre_disaster_tile_8.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/hurricane-florence_00000478_pre_disaster_tile_5.png (deflated 3%)
#   adding: content/damage_classifier_input/pre_images/hurricane-matthew_00000261_pre_disaster_tile_2.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000008_pre_disaster_tile_2.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/mexico-earthquake_00000066_pre_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/socal-fire_00001366_pre_disaster_tile_7.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/mexico-earthquake_00000150_pre_disaster_tile_0.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/socal-fire_00000226_pre_disaster_tile_3.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-michael_00000136_pre_disaster_tile_5.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000151_pre_disaster_tile_0.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000422_pre_disaster_tile_7.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/socal-fire_00001063_pre_disaster_tile_3.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-matthew_00000228_pre_disaster_tile_3.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/hurricane-florence_00000460_pre_disaster_tile_5.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/midwest-flooding_00000043_pre_disaster_tile_8.png (deflated 3%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000075_pre_disaster_tile_4.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/socal-fire_00001245_pre_disaster_tile_7.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000216_pre_disaster_tile_7.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000519_pre_disaster_tile_2.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/santa-rosa-wildfire_00000355_pre_disaster_tile_0.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/socal-fire_00000987_pre_disaster_tile_2.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000482_pre_disaster_tile_0.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-florence_00000180_pre_disaster_tile_2.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/socal-fire_00001078_pre_disaster_tile_6.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-harvey_00000379_pre_disaster_tile_4.png (deflated 1%)
#   adding: content/damage_classifier_input/pre_images/hurricane-matthew_00000390_pre_disaster_tile_2.png (deflated 2%)
#   adding: content/damage_classifier_input/pre_images/hurricane-matthew_00000075_pre_disaster_tile_0.png (deflated 1%)

# %% [markdown]
# ## Extract Test Data
#
# Unzipping the test dataset from Google Drive to a local directory for faster access.

# %%
import os
import shutil

# Define Paths for Test Data
ZIP_TEST_SOURCE = "/content/drive/My Drive/CAIS++ Mini Project + Final Project/xview2/test/processed_data_test/processed_binary_test.zip"
EXTRACT_TEST_DEST = "/content/test_dataset"

# Copy & Unzip Test Data
if not os.path.exists(EXTRACT_TEST_DEST):
    print("Copying test zip from Drive...")
    shutil.copy(ZIP_TEST_SOURCE, "/content/temp_test_data.zip")

    print("Unzipping test data...")
    shutil.unpack_archive("/content/temp_test_data.zip", EXTRACT_TEST_DEST)

    # Cleanup
    os.remove("/content/temp_test_data.zip")
    print(f"Test data ready at {EXTRACT_TEST_DEST}")
else:
    print("Test data already extracted!")
# Out:
# Copying test zip from Drive...
# Unzipping test data...
# Test data ready at /content/test_dataset

# %%
import torch
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
import numpy as np


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# i took same BinaryBuildingDataset class and transform from training setup
test_dataset = BinaryBuildingDataset(EXTRACT_TEST_DEST, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

print(f"Test dataset size: {len(test_dataset)}")

model.eval()

test_probs = []
test_labels = []
test_preds = []

threshold = 0.5

with torch.no_grad():
    for imgs, labels in tqdm(test_loader, desc="Test Inference"):
        imgs = imgs.to(device)

        logits = model(imgs)
        probs = torch.sigmoid(logits)
        preds = (probs > threshold).float()

        test_probs.extend(probs.cpu().numpy().tolist())
        test_labels.extend(labels.numpy().tolist())
        test_preds.extend(preds.cpu().numpy().tolist())

# store paths for filtering later
test_paths = test_dataset.img_paths

print("Inference complete.")
# Out:
# Test dataset size: 16794
# Test Inference:   0%|          | 0/525 [00:00<?, ?it/s]
# Inference complete.

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

y_test_true = np.array(test_labels, dtype=int)
y_test_pred = np.array(test_preds, dtype=int)

print("Confusion Matrix (rows=true, cols=pred):")
print(confusion_matrix(y_test_true, y_test_pred))

print("\nClassification Report:")
print(classification_report(y_test_true, y_test_pred,
                            target_names=["no_buildings", "has_buildings"]))
# Out:
# Confusion Matrix (rows=true, cols=pred):
# [[6223  365]
#  [ 808 9398]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#  no_buildings       0.89      0.94      0.91      6588
# has_buildings       0.96      0.92      0.94     10206
#
#      accuracy                           0.93     16794
#     macro avg       0.92      0.93      0.93     16794
#  weighted avg       0.93      0.93      0.93     16794

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Generate report as a dictionary using the previously computed predictions
report_dict = classification_report(y_test_true, y_test_pred,
                                    target_names=["no_buildings", "has_buildings"],
                                    output_dict=True)

# Convert to DataFrame for easier plotting
classes = ["no_buildings", "has_buildings"]
metrics = ["precision", "recall", "f1-score"]

# Extract specific metrics for the classes
df_metrics = pd.DataFrame({metric: [report_dict[c][metric] for c in classes]
                           for metric in metrics}, index=classes)

# Plot
ax = df_metrics.plot(kind='bar', figsize=(10, 6), rot=0)
plt.title("Precision, Recall, and F1-Score by Class")
plt.ylabel("Score")
plt.ylim(0, 1.1)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Annotate bars
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2115729316.py in <cell line: 0>()
#       3
#       4 # Generate report as a dictionary using the previously computed predictions
# ----> 5 report_dict = classification_report(y_test_true, y_test_pred,
#       6                                     target_names=["no_buildings", "has_buildings"],
#       7                                     output_dict=True)
#
# NameError: name 'classification_report' is not defined

# %% [markdown]
# ## Filter and Pair Test Data
#
# We now identify post-disaster tiles from the test set that are predicted to contain buildings (probability > 0.5). For each valid post-tile, we find its matching pre-disaster tile and copy both (along with masks) to a clean export directory.

# %%
import os
import shutil
import pandas as pd

# 1. Setup Export Directory
EXPORT_TEST_DIR = "/content/damage_classifier_test_input"

PRE_IMG_DIR = os.path.join(EXPORT_TEST_DIR, "pre_images")
POST_IMG_DIR = os.path.join(EXPORT_TEST_DIR, "post_images")
PRE_MASK_DIR = os.path.join(EXPORT_TEST_DIR, "pre_masks")
POST_MASK_DIR = os.path.join(EXPORT_TEST_DIR, "post_masks")

os.makedirs(PRE_IMG_DIR, exist_ok=True)
os.makedirs(POST_IMG_DIR, exist_ok=True)
os.makedirs(PRE_MASK_DIR, exist_ok=True)
os.makedirs(POST_MASK_DIR, exist_ok=True)

# Source Directories from Test Set
TEST_IMG_DIR = os.path.join(EXTRACT_TEST_DEST, "images")
TEST_MASK_DIR = os.path.join(EXTRACT_TEST_DEST, "masks")

filter_threshold = 0.5
paired_test_records = []

# 2. Iterate and Filter
for path, prob in zip(test_paths, test_probs):
    fname_post = os.path.basename(path)

    # Check if it's a post-disaster tile
    if "post_disaster" not in fname_post:
        continue

    # Check if probability exceeds threshold
    if prob <= filter_threshold:
        continue

    # 3. Find Matching Pre-Disaster Tile
    fname_pre = fname_post.replace("post_disaster", "pre_disaster")
    pre_img_path = os.path.join(TEST_IMG_DIR, fname_pre)

    if not os.path.exists(pre_img_path):
        # Skip if no matching pre tile exists
        continue

    # 4. Copy Images
    dst_post_img = os.path.join(POST_IMG_DIR, fname_post)
    dst_pre_img = os.path.join(PRE_IMG_DIR, fname_pre)
    shutil.copy2(path, dst_post_img)
    shutil.copy2(pre_img_path, dst_pre_img)

    # 5. Copy Masks (if they exist)
    post_mask_src = os.path.join(TEST_MASK_DIR, fname_post)
    pre_mask_src = os.path.join(TEST_MASK_DIR, fname_pre)

    dst_post_mask = None
    dst_pre_mask = None

    if os.path.exists(post_mask_src):
        dst_post_mask = os.path.join(POST_MASK_DIR, fname_post)
        shutil.copy2(post_mask_src, dst_post_mask)

    if os.path.exists(pre_mask_src):
        dst_pre_mask = os.path.join(PRE_MASK_DIR, fname_pre)
        shutil.copy2(pre_mask_src, dst_pre_mask)

    # 6. Record Metadata
    paired_test_records.append({
        "pre_image": dst_pre_img,
        "post_image": dst_post_img,
        "pre_mask": dst_pre_mask,
        "post_mask": dst_post_mask,
        "building_prob_post": prob,
    })

print(f"Processing complete. Found {len(paired_test_records)} valid pre/post pairs in test set.")
# Out:
# Processing complete. Found 4857 valid pre/post pairs in test set.

# %%
# Save Metadata CSV
test_pairs_df = pd.DataFrame(paired_test_records)
csv_path = os.path.join(EXPORT_TEST_DIR, "paired_test_building_tiles.csv")
test_pairs_df.to_csv(csv_path, index=False)

print("Saved paired test tiles CSV to:", csv_path)
test_pairs_df.head()
# Out:
# Saved paired test tiles CSV to: /content/damage_classifier_test_input/paired_test_building_tiles.csv
#                                            pre_image  \
# 0  /content/damage_classifier_test_input/pre_imag...
# 1  /content/damage_classifier_test_input/pre_imag...
# 2  /content/damage_classifier_test_input/pre_imag...
# 3  /content/damage_classifier_test_input/pre_imag...
# 4  /content/damage_classifier_test_input/pre_imag...
#
#                                           post_image  \
# 0  /content/damage_classifier_test_input/post_ima...
# 1  /content/damage_classifier_test_input/post_ima...
# 2  /content/damage_classifier_test_input/post_ima...
# 3  /content/damage_classifier_test_input/post_ima...
# 4  /content/damage_classifier_test_input/post_ima...
#
#                                             pre_mask  \
# 0  /content/damage_classifier_test_input/pre_mask...
# 1  /content/damage_classifier_test_input/pre_mask...
# 2  /content/damage_classifier_test_input/pre_mask...
# 3  /content/damage_classifier_test_input/pre_mask...
# 4  /content/damage_classifier_test_input/pre_mask...
#
#                                            post_mask  building_prob_post
# 0  /content/damage_classifier_test_input/post_mas...            0.999685
# 1  /content/damage_classifier_test_input/post_mas...            1.000000
# 2  /content/damage_classifier_test_input/post_mas...            1.000000
# 3  /content/damage_classifier_test_input/post_mas...            0.999987
# 4  /content/damage_classifier_test_input/post_mas...            0.999999

# %%
# Zip and Move to Drive
# !zip -r damage_classifier_test_input.zip /content/damage_classifier_test_input
# !mv damage_classifier_test_input.zip "/content/drive/MyDrive/CAIS++ Mini Project + Final Project/"

print("\nExport complete! 'damage_classifier_test_input.zip' has been saved to your Drive.")
# Out:
#   adding: content/damage_classifier_test_input/ (stored 0%)
#   adding: content/damage_classifier_test_input/post_masks/ (stored 0%)
#   adding: content/damage_classifier_test_input/post_masks/hurricane-harvey_00000033_post_disaster_tile_4.png (deflated 23%)
#   adding: content/damage_classifier_test_input/post_masks/socal-fire_00
)
#   adding: content/damage_classifier_test_input/post_masks/midwest-flooding_00000363_post_disaster_tile_2.png (deflated 78%)
#   adding: content/damage_classifier_test_input/post_masks/hurricane-florence_00000448_post_disaster_tile_1.png (deflated 50%)
#   adding: content/damage_classifier_test_input/post_masks/socal-fire_00001189_post_disaster_tile_3.png (deflated 30%)
#   adding: content/damage_classifier_test_input/post_masks/socal-fire_00001188_post_disaster_tile_5.png (deflated 34%)
#   adding: content/damage_classifier_test_input/post_masks/santa-rosa-wildfire_00000086_post_disaster_tile_8.png (deflated 34%)
#   adding: content/damage_classifier_test_input/post_masks/palu-tsunami_00000158_post_disaster_tile_1.png (deflated 37%)
#   adding: content/damage_classifier_test_input/post_masks/hurricane-michael_00000191_post_disaster_tile_5.png (deflated 47%)
#   adding: content/damage_classifier_test_input/post_masks/hurricane-harvey_00000485_post_disaster_tile_0.png (deflated 18%)
#   adding: content/damage_classifier_test_input/post_masks/midwest-flooding_00000274_post_disaster_tile_1.png (deflated 27%)
#   adding: content/damage_classifier_test_input/post_masks/mexico-earthquake_00000063_post_disaster_tile_1.png (deflated 10%)
#   adding: content/damage_classifier_test_input/post_masks/santa-rosa-wildfire_00000178_post_disaster_tile_6.png (deflated 40%)
#   adding: content/damage_classifier_test_input/post_masks/socal-fire_00001219_post_disaster_tile_5.png (deflated 59%)
#   adding: content/damage_classifier_test_input/post_masks/hurricane-harvey_00000328_post_disaster_tile_6.png (deflated 25%)
#   adding: content/damage_classifier_test_input/post_masks/mexico-earthquake_00000190_post_disaster_tile_5.png (deflated 25%)
#   adding: content/damage_classifier_test_input/post_masks/hurricane-michael_00000071_post_disaster_tile_0.png (deflated 58%)
#   adding: content/damage_classifier_test_input/post_masks/socal-fire_00000621_post_disaster_tile_8.png (deflated 30%)
#   adding: content/damage_classifier_test_input/post_masks/hurricane-harvey_00000143_post_disaster_tile_7.png (deflated 62%)
#   adding: content/damage_classifier_test_input/post_images/ (stored 0%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-harvey_00000033_post_disaster_tile_4.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/socal-fire_00000815_post_disaster_tile_3.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/socal-fire_00000815_post_disaster_tile_6.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/midwest-flooding_00000396_post_disaster_tile_2.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-florence_00000286_post_disaster_tile_6.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-michael_00000176_post_disaster_tile_7.png (deflated 1%)
#   adding: content/damage_classifier_test_input/post_images/midwest-flooding_00000128_post_disaster_tile_3.png (deflated 1%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-harvey_00000468_post_disaster_tile_5.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/santa-rosa-wildfire_00000038_post_disaster_tile_2.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-michael_00000507_post_disaster_tile_8.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-harvey_00000297_post_disaster_tile_5.png (deflated 1%)
#   adding: content/damage_classifier_test_input/post_images/mexico-earthquake_00000131_post_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/socal-fire_00000431_post_disaster_tile_5.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/santa-rosa-wildfire_00000292_post_disaster_tile_6.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-michael_00000471_post_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-harvey_00000368_post_disaster_tile_5.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/socal-fire_00000893_post_disaster_tile_6.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-michael_00000518_post_disaster_tile_8.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-florence_00000211_post_disaster_tile_8.png (deflated 1%)
#   adding: content/damage_classifier_test_input/post_images/palu-tsunami_00000114_post_disaster_tile_8.png (deflated 1%)
#   adding: content/damage_classifier_test_input/post_images/palu-tsunami_00000038_post_disaster_tile_0.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-harvey_00000465_post_disaster_tile_3.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/socal-fire_00000325_post_disaster_tile_2.png (deflated 1%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-matthew_00000022_post_disaster_tile_1.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-harvey_00000150_post_disaster_tile_0.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-harvey_00000112_post_disaster_tile_0.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-matthew_00000227_post_disaster_tile_6.png (deflated 1%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-florence_00000150_post_disaster_tile_5.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/socal-fire_00000294_post_disaster_tile_3.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/midwest-flooding_00000008_post_disaster_tile_6.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-matthew_00000010_post_disaster_tile_4.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/socal-fire_00000783_post_disaster_tile_6.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/santa-rosa-wildfire_00000360_post_disaster_tile_3.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/palu-tsunami_00000120_post_disaster_tile_3.png (deflated 1%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-michael_00000254_post_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/midwest-flooding_00000256_post_disaster_tile_2.png (deflated 1%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-michael_00000477_post_disaster_tile_6.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-michael_00000191_post_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-michael_00000113_post_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/socal-fire_00000942_post_disaster_tile_1.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/midwest-flooding_00000048_post_disaster_tile_3.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/santa-rosa-wildfire_00000145_post_disaster_tile_8.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-michael_00000526_post_disaster_tile_7.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-florence_00000268_post_disaster_tile_7.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-matthew_00000037_post_disaster_tile_8.png (deflated 1%)
#   adding: content/damage_classifier_test_input/post_images/midwest-flooding_00000323_post_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/midwest-flooding_00000361_post_disaster_tile_6.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/palu-tsunami_00000163_post_disaster_tile_0.png (deflated 1%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-matthew_00000022_post_disaster_tile_5.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-florence_00000265_post_disaster_tile_2.png (deflated 1%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-florence_00000318_post_disaster_tile_1.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/socal-fire_00000749_post_disaster_tile_1.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/socal-fire_00000753_post_disaster_tile_0.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/socal-fire_00000889_post_disaster_tile_0.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-florence_00000249_post_disaster_tile_3.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-michael_00000534_post_disaster_tile_3.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/socal-fire_00000568_post_disaster_tile_6.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-harvey_00000062_post_disaster_tile_4.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/midwest-flooding_00000011_post_disaster_tile_8.png (deflated 2%)
#   adding: content/damage_classifier_test_input/post_images/santa-rosa-wildfire_00000089_post_disaster_tile_4.png (deflated 3%)
#   adding: content/damage_classifier_test_input/post_images/hurricane-michael_00000378_post_disaster_tile_8.png
#
#
# zip error: Interrupted (aborting)
# mv: cannot stat 'damage_classifier_test_input.zip': No such file or directory
#
# Export complete! 'damage_classifier_test_input.zip' has been saved to your Drive.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

labels = ["no_buildings", "has_buildings"]

cm = confusion_matrix(val_labels, val_preds, labels=list(range(len(labels))), normalize='true')

fig, ax = plt.subplots(figsize=(10, 8))  # <-- increase figure size here
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap='Blues', ax=ax)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3627243223.py in <cell line: 0>()
#       4 labels = ["no_buildings", "has_buildings"]
#       5
# ----> 6 cm = confusion_matrix(val_labels, val_preds, labels=list(range(len(labels))), normalize='true')
#       7
#       8 fig, ax = plt.subplots(figsize=(10, 8))  # <-- increase figure size here
#
# NameError: name 'val_labels' is not defined
